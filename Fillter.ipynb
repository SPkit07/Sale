# %%
import pandas as pd 
import openpyxl
from datetime import datetime

# %%
df = pd.read_excel(r'C:\Users\KS\Desktop\สมุดงาน1.xlsx')

# %%
df[df['wef'].apply(lambda x: isinstance(x,(datetime, pd.Timestamp))) == True]
# Out:
#                     wef
# 1   2569-01-01 00:00:00
# 2   2569-01-02 00:00:00
# 3   2569-01-03 00:00:00
# 4   2569-01-04 00:00:00
# 5   2569-01-05 00:00:00
# 6   2569-01-06 00:00:00
# 7   2569-01-07 00:00:00
# 8   2569-01-08 00:00:00
# 9   2569-01-09 00:00:00
# 10  2569-01-10 00:00:00
# 11  2569-01-11 00:00:00
# 12  2569-01-12 00:00:00
# 13  2569-01-13 00:00:00
# 14  2569-01-14 00:00:00
# 15  2569-01-15 00:00:00
# 16  2569-01-16 00:00:00
# 17  2569-01-17 00:00:00
# 18  2569-01-18 00:00:00
# 19  2569-01-19 00:00:00
# 20  2569-01-20 00:00:00
# 21  2569-01-21 00:00:00
# 22  2569-01-22 00:00:00
# 23  2569-01-23 00:00:00
# 24  2569-01-24 00:00:00
# 25  2569-01-25 00:00:00
# 26  2569-01-26 00:00:00
# 27  2569-01-27 00:00:00
# 28  2569-01-28 00:00:00
# 29  2569-01-29 00:00:00
# 30  2569-01-30 00:00:00
# 31  2569-01-31 00:00:00

# %%
pd.to_datetime(df['wef'],errors='coerce')
# Out:
# C:\Users\KS\AppData\Local\Temp\ipykernel_4316\1089356664.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(df['wef'],errors='coerce')
# 0    NaT
# 1    NaT
# 2    NaT
# 3    NaT
# 4    NaT
# 5    NaT
# 6    NaT
# 7    NaT
# 8    NaT
# 9    NaT
# 10   NaT
# 11   NaT
# 12   NaT
# 13   NaT
# 14   NaT
# 15   NaT
# 16   NaT
# 17   NaT
# 18   NaT
# 19   NaT
# 20   NaT
# 21   NaT
# 22   NaT
# 23   NaT
# 24   NaT
# 25   NaT
# 26   NaT
# 27   NaT
# 28   NaT
# 29   NaT
# 30   NaT
# 31   NaT
# 32   NaT
# Name: wef, dtype: datetime64[ns]
